# %% [markdown]
# # Q1.Write a python program which searches all the product under a particular product from www.amazon.in. The
# product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for
# guitars

# %%
import pandas as pd
from selenium import webdriver
import warnings 
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import requests

driver=webdriver.Chrome(r"C:\Users\HP\Downloads\chromedriver_win32\chromedriver.exe")

driver.get("https://www.amazon.in/")

gtar=driver.find_element(By.XPATH, '/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input')
gtar.send_keys('guitar')

srch=driver.find_element(By.XPATH, '/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input')
srch.click()

# %%
guitar=[]
start=0
end=3
for page in range(start, end):
    url=driver.find_elements(By.XPATH, '//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')
    for i in url:
            guitar.append(i.get_attribute('href'))
            
            nxtbtn=driver.find_elements(By.XPATH, '//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]' )

# %%
print(len(guitar))       
guitar
# Out:
# 204
# ['https://www.amazon.in/sspa/click?ie=UTF8&spc=MTo0MTA5ODk4MTU1MjA3NDE6MTY4MTYxNDI1MDpzcF9hdGY6MjAxNDY1NDcyNjU3OTg6OjA6Og&url=%2FMedellin-Acoustic-adjustable-Truss-rod-learning%2Fdp%2FB0BMKX4HNP%2Fref%3Dsr_1_1_sspa%3Fkeywords%3Dguitar%26qid%3D1681614250%26sr%3D8-1-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1',
#  'https://www.amazon.in/sspa/click?ie=UTF8&spc=MTo0MTA5ODk4MTU1MjA3NDE6MTY4MTYxNDI1MDpzcF9hdGY6MjAxMjE3ODQyNDA5OTg6OjA6Og&url=%2FKadence-Frontier-Acoustic-Guitar-Equalizer%2Fdp%2FB01HRIHJWY%2Fref%3Dsr_1_2_sspa%3Fkeywords%3Dguitar%26qid%3D1681614250%26sr%3D8-2-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1',
#  'https://www.amazon.in/sspa/click?ie=UTF8&spc=MTo0MTA5ODk4MTU1MjA3NDE6MTY4MTYxNDI1MDpzcF9hdGY6MjAwOTY2MDg3NTA0OTg6OjA6Og&url=%2FKadence-Frontier-Acoustic-Guitar-Strings%2Fdp%2FB01GDZ46AA%2Fref%3Dsr_1_3_sspa%3Fkeywords%3Dguitar%26qid%3D1681614250%26sr%3D8-3-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1%26smid%3DAM04Z7MH4HSDD',
# ...

# %% [markdown]
# # Q2: Scrape "Brand Name", "Name of the Product", "Price", "Return/Exchange", "Expected Delivery", "Availability" and “Product URL

# %%
brandname=[]
productname=[]
price=[]
retu=[]
exp_delivery=[]
avail=[]
prourl=[]

for i in guitar:
    driver.get(i)
    time.sleep(2)
    try:
        brand=driver.find_element(By.XPATH, '/html/body/div[2]/div[2]/div[5]/div[3]/div[4]/div[44]/div/table/tbody/tr[1]/td[2]/span')
        brandname.append(brand.text)
    except NoSuchElementException:
        brandname.append(_)
        
for j in guitar:
    driver.get(j)
    time.sleep(2)
    try:
        pname=driver.find_element(By.XPATH, '/html/body/div[2]/div[2]/div[5]/div[3]/div[4]/div[35]/div[1]/div[3]/div/div/div/span[2]')
        productname.append(pname.text)
    except NoSuchElementException:
        productname.append(_)
                       
for k in guitar:
    driver.get(k)
    time.sleep(2)
    try:
        gprice=driver.find_element(By.XPATH, '/html/body/div[2]/div[2]/div[5]/div[3]/div[4]/div[10]/div[3]/div[1]/span[2]/span[2]/span[2]')
        price.append(gprice.text)
    except NoSuchElementException:
        price.append(_)

for l in guitar:
    driver.get(l)
    time.sleep(2)
    try:
        retex=driver.find_element(By.XPATH, '/html/body/div[2]/div[2]/div[5]/div[3]/div[4]/div[22]/div[2]/div/div/div/div[2]/div/ol/li[3]/div/span/div[2]/a')
        retu.append(retex.text)
    except NoSuchElementException:
        retu.append(_)
        
for m in guitar:
    driver.get(m)
    time.sleep(2)
    try:
        exd=driver.find_element(By.XPATH, '/html/body/div[2]/div[2]/div[5]/div[3]/div[1]/div[3]/div/div[1]/div/div/div/form/div/div/div/div/div[3]/div/div[2]/div[9]/div[1]/div/div/div[1]/span/span')
        exp_delivery.append(exd.text)
    except NoSuchElementException:
        exp_delivery.append(_)
                        
for q in guitar:
    driver.get(q)
    time.sleep(2)
    try:
        av=driver.find_element(By.XPATH, '/html/body/div[2]/div[2]/div[6]/div[3]/div[1]/div[3]/div/div[1]/div/div/div/form/div/div/div/div/div[3]/div/div[4]/div/div[1]/span')
        avail.append(av.text)
    except NoSuchElementException:
        avail.append(_)       
        
for op in guitar:
    driver.get(op)
    time.sleep(2)
    try:
        purl=driver.find_element(By.XPATH, '//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')
        prourl.append(purl.text)
    except NoSuchElementException:
        prourl.append(_)

# %%
 print(len(brandname),len(productname),len(price), len(retu),len(exp_delivery),len(avail), len(prourl))
# Out:
# 204 204 204 204 204 204 204

# %%
import pandas as pd
df=pd.DataFrame({'Brand name':brandname,'Product Name':productname,'Price':price,'Return/Exchange':retu,'Expected Delivery':exp_delivery,'Availaility':avail, 'Product URL':prourl})
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19204\834693324.py in <module>
#       1 import pandas as pd
# ----> 2 df=pd.DataFrame({'Brand name':brandname,'Product Name':productname,'Price':price,'Return/Exchange':retu,'Expected Delivery':exp_delivery,'Availaility':avail, 'Product URL':prourl})
#       3 df
#
# NameError: name 'brandname' is not defined

# %% [markdown]
# # Q3:Write a python program to access the search bar and search button on images.google.com and scrape 10images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes’.

# %%
import pandas as pd
from selenium import webdriver
import warnings 
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import requests

gdriver=webdriver.Chrome(r"C:\Users\HP\Downloads\chromedriver_win32\chromedriver.exe")

gdriver.get("https://images.google.com/")

###FRUITS

fsrch=gdriver.find_element(By.XPATH, '//textarea[@class="gLFyf"]')
fsrch.send_keys('fruits')

entr=gdriver.find_element(By.XPATH, '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button')
gdriver.execute_script("arguments[0].click();", entr)

for _ in range(20):
    gdriver.execute_script("window.scrollBy(0,100)")
    
frtimges = gdriver.find_elements(By.XPATH, '//img[@class="rg_i Q4LuWd"]')

frt_url = []
frt_data = []

for frt in frtimges:
    source = frt.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            frt_url.append(source)
            
for i in range(len(frt_url)):
    if i > 10:
        break
    print("Downloading images {0} of {1} in fruit images" .format(i,10))
    response=requests.get(frt_url[i])
    file=open(r"C:\Users\HP\Desktop\fliprobo" +str(i)+".jpg","wb")
    file.write(response.content)

# %%
#Scraping CARS

# %%
gdriver.get("https://images.google.com/")

carsrch=gdriver.find_element(By.XPATH, '//textarea[@class="gLFyf"]')
carsrch.send_keys('Cars')

carentr=gdriver.find_element(By.XPATH, '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button')
gdriver.execute_script("arguments[0].click();", carentr)

for _ in range(20):
    gdriver.execute_script("window.scrollBy(0,100)")
    
carimges = gdriver.find_elements(By.XPATH, '//img[@class="rg_i Q4LuWd"]')

car_url = []
car_data = []

for car in carimges:
    csource = car.get_attribute('src')
    if csource is not None:
        if(csource[0:4] == 'http'):
            car_url.append(csource)
            
for i in range(len(car_url)):
    if i > 10:
        break
    print("Downloading images {0} of {1} in Car images" .format(i,10))
    response=requests.get(car_url[i])
    file=open(r"C:\Users\HP\Desktop\fliprobo" +str(i)+".jpg","wb")
    file.write(response.content)

# %%
#Scraping Machine Learning Images

# %%
gdriver.get("https://images.google.com/")

mlsrch=gdriver.find_element(By.XPATH, '//textarea[@class="gLFyf"]')
mlsrch.send_keys('Machine Learning')

mlentr=gdriver.find_element(By.XPATH, '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button')
gdriver.execute_script("arguments[0].click();", mlentr)

for _ in range(20):
    gdriver.execute_script("window.scrollBy(0,100)")
    
mlimges = gdriver.find_elements(By.XPATH, '//img[@class="rg_i Q4LuWd"]')

ml_url = []
ml_data = []

for ml in mlimges:
    msource = ml.get_attribute('src')
    if msource is not None:
        if(msource[0:4] == 'http'):
               ml_url.append(msource)
            
for i in range(len(ml_url)):
    if i > 10:
        break
    print("Downloading images {0} of {1} in Machine Learning images" .format(i,10))
    response=requests.get(ml_url[i])
    file=open(r"C:\Users\HP\Desktop\fliprobo" +str(i)+".jpg","wb")
    file.write(response.content)

# %%
#Scraping Guitar images

# %%
gdriver.get("https://images.google.com/")

guitar_srch=gdriver.find_element(By.XPATH, '//textarea[@class="gLFyf"]')
guitar_srch.send_keys('Guitar')

guitar_entr=gdriver.find_element(By.XPATH, '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button')
gdriver.execute_script("arguments[0].click();", guitar_entr)

for _ in range(20):
    gdriver.execute_script("window.scrollBy(0,100)")
    
guitar_imges = gdriver.find_elements(By.XPATH, '//img[@class="rg_i Q4LuWd"]')

guitar_url = []
guitar_data = []

for guitar in guitar_imges:
    gsource = guitar.get_attribute('src')
    if gsource is not None:
        if(gsource[0:4] == 'http'):
               guitar_url.append(gsource)
            
for i in range(len(guitar_url)):
    if i > 10:
        break
    print("Downloading images {0} of {1} in guitar images" .format(i,10))
    response=requests.get(guitar_url[i])
    file=open(r"C:\Users\HP\Desktop\fliprobo" +str(i)+".jpg","wb")
    file.write(response.content)

# %%
#Scraping cakes images

# %%
gdriver.get("https://images.google.com/")

cakesrch=gdriver.find_element(By.XPATH, '//textarea[@class="gLFyf"]')
cakesrch.send_keys('Cake')

cake_entr=gdriver.find_element(By.XPATH, '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button')
gdriver.execute_script("arguments[0].click();", cake_entr)

for _ in range(20):
    gdriver.execute_script("window.scrollBy(0,100)")
    
cake_imges = gdriver.find_elements(By.XPATH, '//img[@class="rg_i Q4LuWd"]')

cake_url = []
cake_data = []

for cake in cake_imges:
    cksource = cake.get_attribute('src')
    if cksource is not None:
        if(cksource[0:4] == 'http'):
               cake_url.append(cksource)
            
for i in range(len(cake_url)):
    if i > 10:
        break
    print("Downloading images {0} of {1} in Cake images" .format(i,10))
    response=requests.get(cake_url[i])
    file=open(r"C:\Users\HP\Desktop\fliprobo" +str(i)+".jpg","wb")
    file.write(response.content)

# %% [markdown]
# # Q4: Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com and scrape

# %%
import pandas as pd
from selenium import webdriver
import warnings 
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import requests

odriver=webdriver.Chrome(r"C:\Users\HP\Downloads\chromedriver_win32\chromedriver.exe")
odriver.get("https://www.flipkart.com/")

cls=odriver.find_element(By.XPATH, '/html/body/div[2]/div/div/button')
cls.click()

oneplus=odriver.find_element(By.XPATH, '/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input')
oneplus.send_keys('Oneplus Nord, pixel 4A')

srch=odriver.find_element(By.XPATH, '/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button')
srch.click()

# %%
oneplusnord=[]

op_tags=odriver.find_elements(By.XPATH, '//a[@class="_1fQZEK"]')
for i in op_tags[0:10]:
    optitle=i.get_attribute('href')
    oneplusnord.append(optitle)

# %%
oneplusnord
# Out:
# ['https://www.flipkart.com/oneplus-nord-gray-onyx-256-gb/p/itm49f817b591982?pid=MOBFUE5GGWHFC37J&lid=LSTMOBFUE5GGWHFC37JNXZLYZ&marketplace=FLIPKART&q=Oneplus+Nord%2C+pixel+4A&store=tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=organic&iid=020a5c5f-8326-43cd-9c22-035a396f3b15.MOBFUE5GGWHFC37J.SEARCH&ppt=hp&ppn=homepage&ssid=tsydrcokcg0000001682008885221&qH=51e22a8c2f127b5e',
#  'https://www.flipkart.com/oneplus-nord-blue-marble-256-gb/p/itm49f817b591982?pid=MOBFUE5HUU5ZYGRY&lid=LSTMOBFUE5HUU5ZYGRY4ZWZZN&marketplace=FLIPKART&q=Oneplus+Nord%2C+pixel+4A&store=tyy%2F4io&srno=s_1_2&otracker=search&otracker1=search&fm=organic&iid=020a5c5f-8326-43cd-9c22-035a396f3b15.MOBFUE5HUU5ZYGRY.SEARCH&ppt=hp&ppn=homepage&ssid=tsydrcokcg0000001682008885221&qH=51e22a8c2f127b5e',
# ...

# %%
brandname=[]
smartphonename=[]
color=[]
ram=[]
rom=[]
pcamera=[]
scamera=[]
display_size=[]
bat_cap=[]
price=[]
produrl=[]

for i in oneplusnord:
    odriver.get(i)
    time.sleep(2)
    try:
        brand=odriver.find_element(By.XPATH, '//span[@class="B_NuCI"]')
        brandname.append(brand.text.split("("))
    except NoSuchElementException:
        brandname.append(_)
        
for j in oneplusnord:
    odriver.get(j)
    time.sleep(2)
    try:
        sname=odriver.find_element(By.XPATH, '/html/body/div[1]/div/div[3]/div[1]/div[2]/div[7]/div/div/div[4]/div/div[2]/div[1]/div[1]/table/tbody/tr[5]/td[2]/ul/li')
        smartphonename.append(sname.text)
    except NoSuchElementException:
         smartphonename.append(_)
                       
for k in oneplusnord:
    odriver.get(k)
    time.sleep(2)
    try:
        col=odriver.find_element(By.XPATH, '/html/body/div[1]/div/div[3]/div[1]/div[2]/div[7]/div/div/div[4]/div/div[2]/div/div[1]/table/tbody/tr[4]/td[2]/ul/li')
        color.append(col.text)
    except NoSuchElementException:
        color.append(_)

for l in oneplusnord:
    odriver.get(l)
    time.sleep(2)
    try:
        pram=odriver.find_element(By.XPATH, '/html/body/div[1]/div/div[3]/div[1]/div[2]/div[7]/div/div/div[4]/div/div[2]/div[1]/div[4]/table/tbody/tr[2]/td[2]/ul/li')
        ram.append(pram.text)
    except NoSuchElementException:
        ram.append(_)
        
for m in oneplusnord:
    odriver.get(m)
    time.sleep(2)
    try:
        prom=odriver.find_element(By.XPATH, '/html/body/div[1]/div/div[3]/div[1]/div[2]/div[7]/div/div/div[4]/div/div[2]/div[1]/div[4]/table/tbody/tr[1]/td[2]/ul/li')
        rom.append(prom.text)
    except NoSuchElementException:
        rom.append(_)
                        
for q in oneplusnord:
    odriver.get(q)
    time.sleep(2)
    try:
        pc=odriver.find_element(By.XPATH, '/html/body/div[1]/div/div[3]/div[1]/div[2]/div[7]/div/div/div[4]/div/div[2]/div[1]/div[5]/table/tbody/tr[1]/td[2]/ul/li')
        pcamera.append(pc.text)
    except NoSuchElementException:
        pcamera.append(_)       
        
for op in oneplusnord:
    odriver.get(op)
    time.sleep(2)
    try:
        scam=odriver.find_element(By.XPATH, '/html/body/div[1]/div/div[3]/div[1]/div[2]/div[7]/div/div/div[4]/div/div[2]/div[1]/div[5]/table/tbody/tr[2]/td[2]/ul/li')
        scamera.append(scam.text)
    except NoSuchElementException:
        scamera.append(_)      
        
for q in oneplusnord:
    odriver.get(q)
    time.sleep(2)
    try:
        disp=odriver.find_element(By.XPATH, '/html/body/div[1]/div/div[3]/div[1]/div[2]/div[7]/div/div/div[4]/div/div[2]/div[1]/div[2]/table/tbody/tr[1]/td[2]/ul/li')
        display_size.append(disp.text)
    except NoSuchElementException:
        display_size.append(_)      
        
for r in oneplusnord:
    odriver.get(r)
    time.sleep(2)
    try:
        bat=odriver.find_element(By.XPATH, '/html/body/div[1]/div/div[3]/div[1]/div[2]/div[7]/div/div/div[4]/div/div[2]/div[1]/div[7]/table/tbody/tr/td[2]/ul/li')
        bat_cap.append(bat.text)
    except NoSuchElementException:
        bat_cap.append(_)          
        
for s in oneplusnord:
    odriver.get(s)
    time.sleep(2)
    try:
        prc=odriver.find_element(By.XPATH, '//div[@class="_30jeq3 _16Jk6d"]')
        price.append(prc.text)
    except NoSuchElementException:
        price.append(_)    
        
for t in oneplusnord:
    odriver.get(t)
    time.sleep(2)
    try:
        prod=odriver.find_element(By.XPATH, '//a[@class="_1fQZEK"]')
        produrl.append(prod.text)
    except NoSuchElementException:
        produrl.append(_)

# %%
print(len(brandname),len(smartphonename),len(color),len(ram),len(rom),len(pcamera),len(scamera),len(display_size),len(bat_cap),len(price),len(produrl))
# Out:
# 8 8 8 8 8 8 8 8 8 8 8

# %%
import pandas as pd
oneplusdf=pd.DataFrame({'Brand name':brandname,'Smartphone Name':smartphonename,'Color':color,'RAM':ram,'ROM':rom,'Primary Camera':pcamera, 'Secondary Camera':scamera, 'Display Size':display_size,'Battery Capacity':bat_cap,'Price':price, 'Product URL':produrl})
oneplusdf
# Out:
#                                           Brand name Smartphone Name  \
# 0  [OnePlus Nord , Gray Onyx, 256 GB)  , 12 GB RAM)]     Smartphones
# 1  [OnePlus Nord , Blue Marble, 256 GB)  , 12 GB ...     Smartphones
# 2  [OnePlus Nord , Blue Marble, 128 GB)  , 8 GB R...     Smartphones
# 3    [OnePlus Nord , Gray Onyx, 64 GB)  , 6 GB RAM)]     Smartphones
# 4  [OnePlus Nord , Blue Marble, 64 GB)  , 6 GB RAM)]     Smartphones
# 5   [OnePlus Nord , Gray Onyx, 128 GB)  , 8 GB RAM)]     Smartphones
# 6  [OnePlus Nord CE 2 5G , Gray Mirror, 128 GB)  ...     Smartphones
# 7  [OnePlus Nord CE 2 5G , Gray Mirror, 128 GB)  ...     Smartphones
#
#          Color RAM ROM Primary Camera Secondary Camera Display Size  \
# 0    Gray Onyx
# 1  Blue Marble
# 2  Blue Marble
# 3    Gray Onyx
# 4  Blue Marble
# 5    Gray Onyx
# 6  Gray Mirror
# 7  Gray Mirror
#
#   Battery Capacity    Price  Product URL
# 0                   ₹29,999           19
# 1                   ₹29,999           19
# ...

# %% [markdown]
# # Q5:Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps

# %%
import pandas as pd
from selenium import webdriver
import warnings 
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import requests
import re

ggldriver=webdriver.Chrome(r"C:\Users\HP\Downloads\chromedriver_win32\chromedriver.exe")
ggldriver.get("https://www.google.com/maps")

ggl=ggldriver.find_element(By.XPATH, '/html/body/div[3]/div[9]/div[3]/div[1]/div[1]/div[1]/div[2]/form/div[2]/div[3]/div/input[1]')
ggl.send_keys('Banglore')

gglsrch=ggldriver.find_element(By.XPATH, '/html/body/div[3]/div[9]/div[3]/div[1]/div[1]/div[1]/div[2]/div[1]/button')
gglsrch.click()

# %%
    url_string=ggldriver.current_url
   #print("URL Extracted" ,url_string)
    
    def convert(url_string):
        return tuple(url_string)
    url_string= url_string.split('@')
    url_string=url_string[1].split(',')
    lattitide=url_string[0]
    longitude= url_string[1]
    print("Longitude and lattitude are:", longitude, "and" , lattitide)
# Out:
# Longitude and lattitude are: 73.8937956 and 18.5472357

# %% [markdown]
# # Q6: Write a program to scrap all the available details of best gaming laptops from digit.in.

# %%
import pandas as pd
from selenium import webdriver
import warnings 
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import requests

dgdriver=webdriver.Chrome(r"C:\Users\HP\Downloads\chromedriver_win32\chromedriver.exe")
dgdriver.get("https://www.digit.in/")

dgsrch=dgdriver.find_element(By.XPATH, '/html/body/div[7]/div/div[2]/div[2]/div[4]/ul/li[9]/a')
dgsrch.click()

lap=[]
start=0
end=1
for page in range(start, end):
    url=dgdriver.find_elements(By.XPATH, '//div[@class="left_side"]/a')
    for i in url:
            lap.append(i.get_attribute('href'))

# %%
print(len(lap))       
lap
# Out:
# 10
# ['https://www.digit.in/laptops/msi-titan-gt77-12uhs-12th-gen-core-i9-12900hx-2022-price-303891.html',
#  'https://www.digit.in/laptops/lenovo-legion-7-82td009kin-12th-gen-core-i9-12900hx-2022-price-339045.html',
#  'https://www.digit.in/laptops/dell-new-alienware-x17-r2-d569944win9-12th-gen-core-i9-12900hk-2022-price-309253.html',
#  'https://www.digit.in/laptops/acer-predator-triton-500-se-pt516-52s-12th-gen-core-i7-12700h-2022-price-328956.html',
#  'https://www.digit.in/laptops/omen-by-hp-16-b1371tx-12th-gen-core-i7-12700h-2022-price-290829.html',
#  'https://www.digit.in/laptops/acer-nitro-5-an515-45-nh-qbrsi-007-ryzen-9-5900hx-2022-price-305725.html',
#  'https://www.digit.in/laptops/msi-delta-15-5th-gen-ryzen-9-5900hx-2022-price-288855.html',
#  'https://www.digit.in/laptops/hp-omen-16-c0141ax-ryzen-9-5900hx-2022-price-289331.html',
#  'https://www.digit.in/laptops/lenovo-legion-5-pro-82rf00mgin-12th-gen-core-i7-12700h-2022-price-311997.html',
# ...

# %%
brandname=[]
processor=[]
disp=[]
os=[]
memry=[]
grpro=[]
bdy=[]
price=[]

for i in lap:
    dgdriver.get(i)
    time.sleep(2)
    try:
        lapbrand=dgdriver.find_element(By.XPATH, '/html/body/div[9]/div[1]/div[3]/div[2]/div[7]/div[1]/div[1]/a/h3')
        brandname.append(lapbrand.text)
    except NoSuchElementException:
        brandname.append(_)
        
for j in lap:
    dgdriver.get(j)
    time.sleep(2)
    try:
        pro=dgdriver.find_element(By.XPATH, '/html/body/div[9]/div[1]/div[3]/div[2]/div[7]/div[3]/div[3]/table/tbody/tr[2]/td[3]')
        processor.append(pro.text)
    except NoSuchElementException:
        processor.append(_)
                       
for k in lap:
    dgdriver.get(k)
    time.sleep(2)
    try:
        lapdisp=dgdriver.find_element(By.XPATH, '/html/body/div[9]/div[1]/div[3]/div[2]/div[6]/div[3]/div[3]/table/tbody/tr[3]/td[3]')
        disp.append(lapdisp.text)
    except NoSuchElementException:
        disp.append(_)

for l in lap:
    dgdriver.get(l)
    time.sleep(2)
    try:
        oper=dgdriver.find_element(By.XPATH, '/html/body/div[9]/div[1]/div[3]/div[2]/div[6]/div[3]/div[3]/table/tbody/tr[4]/td[3]')
        os.append(oper.text)
    except NoSuchElementException:
        os.append(_)
        
for m in lap:
    dgdriver.get(m)
    time.sleep(2)
    try:
        mmr=dgdriver.find_element(By.XPATH, '/html/body/div[9]/div[1]/div[3]/div[2]/div[6]/div[3]/div[3]/table/tbody/tr[5]/td[3]')
        memry.append(mmr.text)
    except NoSuchElementException:
        memry.append(_)
        
for n in lap:
    dgdriver.get(m)
    time.sleep(2)
    try:
        gp=dgdriver.find_element(By.XPATH, '/html/body/div[9]/div[1]/div[3]/div[2]/div[6]/div[3]/div[3]/table/tbody/tr[6]/td[3]')
        grpro.append(gp.text)
    except NoSuchElementException:
        grpro.append(_)
          
for p in lap:
    dgdriver.get(p)
    time.sleep(2)
    try:
        lapbdy=dgdriver.find_element(By.XPATH, '/html/body/div[9]/div[1]/div[3]/div[2]/div[6]/div[3]/div[3]/table/tbody/tr[7]/td[3]')
        bdy.append(lapbdy.text)
    except NoSuchElementException:
        bdy.append(_)
        
for q in lap:
    dgdriver.get(q)
    time.sleep(2)
    try:
        laprate=dgdriver.find_element(By.XPATH, '/html/body/div[9]/div[1]/div[3]/div[2]/div[6]/div[3]/div[3]/table/tbody/tr[8]/td[3]')
        price.append(laprate.text)
    except NoSuchElementException:
        price.append(_)

# %%
print(len(brandname),len(processor),len(disp),len(os),len(memry),len(grpro),len(bdy),len(price))
# Out:
# 10 10 10 10 10 10 10 10

# %%
import pandas as pd
lapdf=pd.DataFrame({'Brand name':brandname,'Processor':processor,'Dislpay':disp,'Operating System':os,'Memory':memry,'Graphical Processor':grpro, 'Body':bdy, 'Price':price})
lapdf
# Out:
#                                           Brand name  \
# 0  [https://www.digit.in/laptops/msi-titan-gt77-1...
# 1  [https://www.digit.in/laptops/msi-titan-gt77-1...
# 2  [https://www.digit.in/laptops/msi-titan-gt77-1...
# 3  [https://www.digit.in/laptops/msi-titan-gt77-1...
# 4  [https://www.digit.in/laptops/msi-titan-gt77-1...
# 5  [https://www.digit.in/laptops/msi-titan-gt77-1...
# 6  [https://www.digit.in/laptops/msi-titan-gt77-1...
# 7  [https://www.digit.in/laptops/msi-titan-gt77-1...
# 8  [https://www.digit.in/laptops/msi-titan-gt77-1...
# 9  [https://www.digit.in/laptops/msi-titan-gt77-1...
#
#                                            Processor  \
# 0  [https://www.digit.in/laptops/msi-titan-gt77-1...
# 1  [https://www.digit.in/laptops/msi-titan-gt77-1...
# 2  [https://www.digit.in/laptops/msi-titan-gt77-1...
# 3  [https://www.digit.in/laptops/msi-titan-gt77-1...
# 4  [https://www.digit.in/laptops/msi-titan-gt77-1...
# 5  [https://www.digit.in/laptops/msi-titan-gt77-1...
# ...
